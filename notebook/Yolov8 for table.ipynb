# %%
# !pip install ultralyticsplus==0.0.23 ultralytics==8.0.21
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ultralyticsplus==0.0.23
#   Downloading ultralyticsplus-0.0.23-py3-none-any.whl (11 kB)
# Collecting ultralytics==8.0.21
#   Downloading ultralytics-8.0.21-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 1.2 MB/s eta 0:00:000:00:010:00:01:01
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 990.9 kB/s eta 0:00:00MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting sahi<0.12.0,>=0.11.11
#   Downloading sahi-0.11.15-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 KB 1.1 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /home/ronan/.local/lib/python3.10/site-packages (from ultralyticsplus==0.0.23) (2.2.0)
# Requirement already satisfied: huggingface-hub>=0.12.0 in /home/ronan/.local/lib/python3.10/site-packages (from ultralyticsplus==0.0.23) (0.20.3)
# Requirement already satisfied: tqdm>=4.64.0 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (4.66.1)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 1.4 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.2.2 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (3.8.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/lib/python3/dist-packages (from ultralytics==8.0.21) (5.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (1.12.0)
# Collecting tensorboard>=2.4.1
#   Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: requests>=2.23.0 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (2.31.0)
# Requirement already satisfied: ipython in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (8.21.0)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from ultralytics==8.0.21) (5.9.0)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: Pillow>=7.1.2 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (9.4.0)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.40.0-py2.py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 KB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: torch>=1.7.0 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (2.1.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (1.26.3)
# Requirement already satisfied: torchvision>=0.8.1 in /home/ronan/.local/lib/python3.10/site-packages (from ultralytics==8.0.21) (0.16.2)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (21.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ronan/.local/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ronan/.local/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (4.9.0)
# Requirement already satisfied: filelock in /home/ronan/.local/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (3.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ronan/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ronan/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ronan/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ronan/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (4.47.2)
# Requirement already satisfied: cycler>=0.10 in /home/ronan/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->ultralyticsplus==0.0.23) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ronan/.local/lib/python3.10/site-packages (from pandas->ultralyticsplus==0.0.23) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ronan/.local/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.21) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics==8.0.21) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics==8.0.21) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics==8.0.21) (2020.6.20)
# Requirement already satisfied: shapely>=1.8.0 in /home/ronan/.local/lib/python3.10/site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (2.0.2)
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (8.0.3)
# Collecting pybboxes==0.1.6
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>1.9 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Collecting absl-py>=0.4
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
# Collecting google-auth-oauthlib<2,>=0.5
#   Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Collecting protobuf<4.24,>=3.19.6
#   Using cached protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (59.6.0)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: networkx in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (3.2.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (11.0.2.54)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (8.9.2.26)
# Requirement already satisfied: triton==2.1.0 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (2.1.0)
# Requirement already satisfied: sympy in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: jinja2 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (3.1.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (2.18.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ronan/.local/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ronan/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->ultralytics==8.0.21) (12.3.101)
# Collecting termcolor
#   Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: stack-data in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (2.17.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (3.0.43)
# Requirement already satisfied: decorator in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (0.19.1)
# Requirement already satisfied: exceptiongroup in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (1.2.0)
# Requirement already satisfied: traitlets>=5 in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (5.14.1)
# Requirement already satisfied: matplotlib-inline in /home/ronan/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->ultralytics==8.0.21) (4.8.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 KB 898.0 kB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/ronan/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->ultralytics==8.0.21) (0.8.3)
# Requirement already satisfied: wcwidth in /home/ronan/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ultralytics==8.0.21) (0.2.13)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ronan/.local/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.21) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/ronan/.local/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.21) (2.0.1)
# Requirement already satisfied: pure-eval in /home/ronan/.local/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.21) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ronan/.local/lib/python3.10/site-packages (from sympy->torch>=1.7.0->ultralytics==8.0.21) (1.3.0)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.21) (3.2.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116951 sha256=bd650b1a500923096ba7088666abe0fed9571714f5c6487de7e052b199af3c73
#   Stored in directory: /home/ronan/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: urllib3, terminaltables, termcolor, tensorboard-data-server, pybboxes, pyasn1, protobuf, opencv-python, MarkupSafe, markdown, grpcio, cachetools, absl-py, werkzeug, sentry-sdk, rsa, pyasn1-modules, fire, seaborn, sahi, requests-oauthlib, google-auth, thop, google-auth-oauthlib, tensorboard, ultralytics, ultralyticsplus
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# poetry 1.4.0 requires urllib3<2.0.0,>=1.26.0, but you have urllib3 2.2.0 which is incompatible.
# Successfully installed MarkupSafe-2.1.4 absl-py-2.1.0 cachetools-5.3.2 fire-0.5.0 google-auth-2.27.0 google-auth-oauthlib-1.2.0 grpcio-1.60.0 markdown-3.5.2 opencv-python-4.7.0.72 protobuf-4.23.4 pyasn1-0.5.1 pyasn1-modules-0.3.0 pybboxes-0.1.6 requests-oauthlib-1.3.1 rsa-4.9 sahi-0.11.15 seaborn-0.13.2 sentry-sdk-1.40.0 tensorboard-2.15.1 tensorboard-data-server-0.7.2 termcolor-2.4.0 terminaltables-3.1.10 thop-0.1.1.post2209072238 ultralytics-8.0.21 ultralyticsplus-0.0.23 urllib3-2.2.0 werkzeug-3.0.1

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('keremberke/yolov8m-table-extraction')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
image = "/home/ronan/Asso/tax observatory/taxobservatory_test_set/Acciona_2020_CbCR_1.png"

# perform inference
results = model.predict(image)
# Out:
# Ultralytics YOLOv8.0.21 🚀 Python-3.10.12 torch-2.1.2+cu121 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# image 1/1 /home/ronan/Asso/tax observatory/taxobservatory_test_set/Acciona_2020_CbCR_1.png: 448x640 1 borderless, 793.2ms
# Speed: 10.9ms pre-process, 793.2ms inference, 150.6ms postprocess per image at shape (1, 3, 640, 640)
# tensor([[3.17000e+02, 6.43000e+02, 4.65100e+03, 1.83600e+03, 8.69654e-01, 1.00000e+00]])

# %%
# parse results
result = results[0]
boxes = result.boxes.xyxy # x1, y1, x2, y2
scores = result.boxes.conf
categories = result.boxes.cls
scores = result.probs # for classification models
masks = result.masks # for segmentation models

# observe results
#print(results[0].boxes)
render = render_result(model=model, image=image, result=results[0])
render.show()
