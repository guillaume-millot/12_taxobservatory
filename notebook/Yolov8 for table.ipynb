# %%
# !pip install ultralyticsplus==0.0.23 ultralytics==8.0.21
# Out:
# Collecting ultralyticsplus==0.0.23
#   Using cached ultralyticsplus-0.0.23-py3-none-any.whl (11 kB)
# Collecting ultralytics==8.0.21
#   Using cached ultralytics-8.0.21-py3-none-any.whl (261 kB)
# Requirement already satisfied: huggingface-hub>=0.12.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralyticsplus==0.0.23) (0.20.3)
# Requirement already satisfied: pandas in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralyticsplus==0.0.23) (2.2.0)
# Collecting fire
#   Using cached fire-0.5.0-py2.py3-none-any.whl
# Collecting sahi<0.12.0,>=0.11.11
#   Using cached sahi-0.11.15-py3-none-any.whl (105 kB)
# Requirement already satisfied: numpy>=1.18.5 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (1.26.4)
# Requirement already satisfied: requests>=2.23.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (2.31.0)
# Requirement already satisfied: torch>=1.7.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (2.2.0)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.40.5-py2.py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 KB 1.5 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: Pillow>=7.1.2 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (10.2.0)
# Requirement already satisfied: psutil in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (5.9.8)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (3.8.3)
# Collecting seaborn>=0.11.0
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Collecting thop>=0.1.1
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Collecting opencv-python>=4.6.0
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# Requirement already satisfied: torchvision>=0.8.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (0.17.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (6.0.1)
# Requirement already satisfied: tqdm>=4.64.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (4.66.2)
# Requirement already satisfied: ipython in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ultralytics==8.0.21) (8.21.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (23.2)
# Requirement already satisfied: filelock in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (4.9.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (4.49.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (1.4.5)
# Requirement already satisfied: tzdata>=2022.7 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from pandas->ultralyticsplus==0.0.23) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from pandas->ultralyticsplus==0.0.23) (2024.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.21) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.21) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.21) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.21) (3.3.2)
# Collecting shapely>=1.8.0
#   Downloading shapely-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting terminaltables
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (8.1.7)
# Collecting opencv-python>=4.6.0
#   Using cached opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
# Collecting pybboxes==0.1.6
#   Using cached pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.60.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six>1.9 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (1.16.0)
# Collecting absl-py>=0.4
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Collecting protobuf!=4.24.0,>=3.19.6
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 1.5 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=41.0.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (69.0.3)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.0.106)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (11.4.5.107)
# Requirement already satisfied: sympy in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (1.12)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (2.19.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (2.2.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (11.0.2.54)
# Requirement already satisfied: networkx in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (3.2.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.3.1)
# Requirement already satisfied: jinja2 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (3.1.3)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (8.9.2.26)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.21) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->ultralytics==8.0.21) (12.3.101)
# Collecting termcolor
#   Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: jedi>=0.16 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (0.19.1)
# Requirement already satisfied: exceptiongroup in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (1.2.0)
# Requirement already satisfied: stack-data in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (2.17.2)
# Requirement already satisfied: pexpect>4.3 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (4.9.0)
# Requirement already satisfied: decorator in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from ipython->ultralytics==8.0.21) (5.14.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->ultralytics==8.0.21) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->ultralytics==8.0.21) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ultralytics==8.0.21) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics==8.0.21) (2.1.5)
# Requirement already satisfied: pure-eval in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.21) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.21) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.21) (2.4.1)
# Requirement already satisfied: mpmath>=0.19 in /home/ronan/Asso/tax observatory/cbcReporting_venv/lib/python3.10/site-packages (from sympy->torch>=1.7.0->ultralytics==8.0.21) (1.3.0)
# Installing collected packages: werkzeug, terminaltables, termcolor, tensorboard-data-server, shapely, sentry-sdk, scipy, pybboxes, protobuf, opencv-python, markdown, grpcio, absl-py, tensorboard, fire, seaborn, sahi, thop, ultralytics, ultralyticsplus
# Successfully installed absl-py-2.1.0 fire-0.5.0 grpcio-1.60.1 markdown-3.5.2 opencv-python-4.7.0.72 protobuf-4.25.3 pybboxes-0.1.6 sahi-0.11.15 scipy-1.12.0 seaborn-0.13.2 sentry-sdk-1.40.5 shapely-2.0.3 tensorboard-2.16.2 tensorboard-data-server-0.7.2 termcolor-2.4.0 terminaltables-3.1.10 thop-0.1.1.post2209072238 ultralytics-8.0.21 ultralyticsplus-0.0.23 werkzeug-3.0.1

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('keremberke/yolov8m-table-extraction')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
image = "/home/ronan/Asso/tax observatory/taxobservatory_test_set/Acciona_2020_CbCR_1.png"

# perform inference
results = model.predict(image)
# Out:
# Ultralytics YOLOv8.0.21 🚀 Python-3.10.12 torch-2.2.0+cu121 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# image 1/1 /home/ronan/Asso/tax observatory/taxobservatory_test_set/Acciona_2020_CbCR_1.png: 448x640 1 borderless, 2738.3ms
# Speed: 3.4ms pre-process, 2738.3ms inference, 250.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
# parse results
result = results[0]
boxes = result.boxes.xyxy # x1, y1, x2, y2
scores = result.boxes.conf
categories = result.boxes.cls
scores = result.probs # for classification models
masks = result.masks # for segmentation models

# observe results
#print(results[0].boxes)
render = render_result(model=model, image=image, result=results[0])
render.show()
